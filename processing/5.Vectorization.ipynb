# %% [markdown]
# # Module Import

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import nltk
from nltk import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer

from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.sklearn

import re
import string
import glob
import warnings

fontpath = '/usr/share/fonts/truetype/nanum/Nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.style.use('seaborn-white')
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['figure.figsize'] = [20, 10]
warnings.filterwarnings('ignore')

nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')

# %config InlineBackend.figure_format = 'retina'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jihoonmanse/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jihoonmanse/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     /home/jihoonmanse/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %% [markdown]
# # Count Data Load(cnt_data)

# %%
cnt_data = pd.read_excel('/project/Roblox/kseung/apr/top10_wordcount.xlsx', index_col = 0)
tfidf_data = pd.read_excel('/project/Roblox/kseung/apr/top10_tfidf.xlsx', index_col = 0)
fisher_data = pd.read_excel('/project/Roblox/kseung/apr/top10_fisher.xlsx', index_col=0)

# %%
cnt_data
# Out:
#   Adopt Me! MeepCity Tower of Hell   Piggy Royale High Jailbreak  \
# 0     trade      bro          jump   piggy         guy       guy
# 1       pet    house           guy    yeah        time      wait
# 2       guy      guy          yeah     guy      outfit       cop
# 3    people     yeah          wait     god     diamond      yeah
# 4      wait     wait          time    wait        wait       car
# 5   grandpa    party          easy     key        high    arrest
# 6      neon     meat          game  shovel        cute    police
# 7      yeah     game           god    skin        dorm      card
# 8      feel     play           buy     die        yeah       key
# 9    dragon     cute         level    play       start     store
#
#   Murder Mystery 2 Welcome to Bloxburg Pizza Factory Tycoon Restaurant Tycoon
# 0              guy                 guy                pizza        restaurant
# 1         murderer                yeah                 yeah              yeah
# 2             wait                wait                  buy              cook
# 3          sheriff               pizza                 wait               guy
# 4             yeah               house                  guy             money
# 5             dude                room             customer             table
# 6             kill                time                money               buy
# 7              god                 eat               cheese            people
# 8              bro                girl                 cool              chef
# 9              gun                baby                  bro             thing

# %%
tfidf_data
# Out:
#   Adopt Me! MeepCity Tower of Hell      Piggy Royale High Jailbreak  \
# 0     trade      bro          jump      piggy         guy    arrest
# 1       pet     meep           guy     carrot        dorm       cop
# 2   grandpa     meat          yeah       yeah        time    police
# 3      neon    party         tower        key     diamond       guy
# 4       guy     city    checkpoint     shovel       perry      wait
# 5    potion    chloe          wait        guy      outfit      card
# 6     offer    house          time        god        wait  criminal
# 7    shadow      guy          easy       wait        high       car
# 8     adopt     yeah           god       skin       skirt       rob
# 9    people     wait          game  infection        cute      yeah
#
#   Murder Mystery 2 Welcome to Bloxburg Pizza Factory Tycoon Restaurant Tycoon
# 0         murderer                 guy                pizza        restaurant
# 1          sheriff                yeah             customer              cook
# 2              guy                wait                 yeah              chef
# 3         innocent               pizza                  buy             table
# 4              joe                room                 wait            waiter
# 5             wait          blocksburg                  guy              yeah
# 6           chroma               house               cheese               guy
# 7           murder               bella                money             money
# 8             yeah                time            pepperoni               buy
# 9            knife                food            milkshake          customer

# %%
fisher_data
# Out:
#   Adopt Me! MeepCity  Tower of Hell      Piggy Royale High Jailbreak  \
# 0     trade     meat           jump      piggy        dorm       cop
# 1       pet    party           easy     shovel     diamond    arrest
# 2   grandpa     meep          tower        key      outfit    police
# 3      neon     city     checkpoint     carrot       perry      card
# 4     offer    chloe         double       skin        hair  criminal
# 5    dragon     fish          level  infection        high       rob
# 6    potion      bro           beat       mode     routine      jail
# 7      mega    house           cube       trap       skirt      bank
# 8    shadow    class        rainbow        god      school       car
# 9     adopt  teacher  invincibility       snow       class   officer
#
#   Murder Mystery 2 Welcome to Bloxburg Pizza Factory Tycoon Restaurant Tycoon
# 0         murderer          blocksburg                pizza        restaurant
# 1          sheriff               bella             customer              cook
# 2              joe            birthday               cheese             table
# 3            knife                 mom            pepperoni            waiter
# 4         innocent             pancake            milkshake              chef
# 5           murder              excite              factory             order
# 6           chroma                baby                  buy             sushi
# 7              gun                babe              sausage              dish
# 8            godly                room              dessert         spaghetti
# 9            shoot              shower               banana             money

# %% [markdown]
# # Data Load

# %%
path = '/data/Roblox/'

# %%
lst_dir = glob.glob(path + '/*')

# %%
lst_col = []
for i in lst_dir:
    lst_col.append(i.split('/')[-1])

df = pd.DataFrame(columns=lst_col)
df
# Out:
# Empty DataFrame
# Columns: [Piggy, Adopt Me!, Welcome to Bloxburg, Murder Mystery 2, Jailbreak, Royale High, Restaurant Tycoon, Tower of Hell, Pizza Factory Tycoon, MeepCity]
# Index: []

# %%
lst_data = []
for directory in lst_dir:
    print('=' * 50)
    print('게임 이름: {}'.format(directory.split('/')[-1]))
    print('=' * 50)
    lst_path = glob.glob(directory + '/*')

    lst_text = []
    for txt_path in lst_path:
        print(txt_path)
        with open(txt_path, 'r') as f:
            text = f.read()
        text = [text]
        lst_text += text

    df[directory.split('/')[-1]] = lst_text
# Out:
# ==================================================
# 게임 이름: Piggy
# ==================================================
# /data/Roblox/Piggy/Piggy Season 6 WHISTLING WINTER! (Meisery Skin).txt
# /data/Roblox/Piggy/Piggy Winter Holiday!  Roblox.txt
# /data/Roblox/Piggy/HOW TO GET SNOWPIGGY TRAP in PIGGY WINTER HOLIDAY EVENT MAP.txt
# /data/Roblox/Piggy/SECRET PRIMROSE SKIN! ROBLOX PIGGY WINTER HOLIDAY HUNT.txt
# /data/Roblox/Piggy/Escape The Christmas Winter Holiday Piggy Roblox Map  Cookie Swirl C.txt
# /data/Roblox/Piggy/ROBLOX PIGGY @ the MALL!  Chapter 10 FGTeeV Multiplayer Escape (The Secret is Out).txt
# /data/Roblox/Piggy/ZIZZY IS BACK FOR CHRISTMAS!! - Roblox Piggy Winter Holiday Chapter.txt
# /data/Roblox/Piggy/ROBLOX PIGGY elsa bunny and meisery.txt
# /data/Roblox/Piggy/THE END of Roblox PIGGY!.txt
# /data/Roblox/Piggy/Roblox PIGGY... but with 100 PLAYERS.txt
# ==================================================
# 게임 이름: Adopt Me!
# ==================================================
# /data/Roblox/Adopt Me!/DON'T TAKE ME AWAY FROM MY DAD!! SHE WON'T STOP FOLLOWING ME! ROBLOX ADOPT ME! (Roblox Roleplay).txt
# /data/Roblox/Adopt Me!/Starting on a NEW Account (Part 3 Adopt me).txt
# /data/Roblox/Adopt Me!/I Traded FLY PET POTIONS ONLY in Adopt Me! Roblox Adopt Me Trading Challenge! INSANE Trades!.txt
# 1  CookieSwirl. See? Hello, Cookie fans. Today I ...
# 2  So today we're gonna be doing a special challe...
# 3  Hi, I'm Tankfish, and I'm a convicted war crim...
# 4  I'm gonna quickly phase through the wall reall...
# 5  Dude, it's 03:00 A.m.. We're not supposed to p...
# 6  I could transform into Donald Trump. Oh, what ...
# 7  He wants to switch teeth. \nWhat? Juan. I drov...
# 8  Yo, let's go. Alpha alexa. \nYou just fell on ...
# 9  So I was playing Roblox jailbreak with a fan w...
#
#                                     Murder Mystery 2  \
# 0  Wait, don't die. Oh, no. Good job. Go get him....
# 1  Don't forget to use star code Ant when you buy...
# 2  Leave a like and subscribe in the next 3.2 sec...
# 3  Hey guys, today we're gonna be stabbing people...
# 4  Since I have no friends in Quarantine, I decid...
# 5  So I am the murderer two times in a row. Alrig...
# 6  Hey, get down from there, you fake weirdo. You...
# 7  Can you not point that gun on me? It makes me ...
# 8  Filing sorry, filing cabinet. Crate rock. So L...
# 9  How is it going? Databases? No data here. And ...
#
#                                  Welcome to Bloxburg  \
# 0  Are you guys ready for a build challenge? No. ...
# 1  Guys, we have exciting news. Woo. What is it? ...
# 2  Hey guys, it's Krie turn back. It's at tomorro...
# 3  Welcome back to the channel, guys. Today we ha...
# 4  Oh, guys, I was just taking the longest nap in...
# 5  Hey, guys, it's Janet and Kate. Welcome back t...
# 6  So today in Bloxburg, my boyfriend and I staye...
# 7  Guys. The game that I helped make survive Albe...
# 8  Amber? Yeah. Come in here a SEC. I can't make ...
# 9  And man, this video's crazy. This one girl, sh...
#
#                                 Pizza Factory Tycoon  \
# 0  It's the evil girls that try to stab us. She s...
# 1  What is up, my family? We are back, and we are...
# 2  Should I do it? Should I do it? Hey, yo, what'...
# 3  I'm about to become the Hulk. But what the oh,...
# 4  In this video, we unlock every single thing yo...
# 5  Oh, wow, that felt great. Hey, everybody. Welc...
# 6  Hey, guys. Jen what's happening, dude? And wel...
# 7  Cookies. Whirl. See? Hello, chocolatey chippy ...
# 8  One, two, three. Go, go. Know how you're faste...
# 9  Hello, everyone, and welcome back to on the Vo...
#
#                                    Restaurant Tycoon
# 0  So I always wanted to own a five star restaura...
# 1  Hey, guys. It's Korean. Tarak inside. Roblox. ...
# 2  Alright. Good morning, everybody. And today is...
# 3  \nMMM stars. Guys, what are you doing? Are you...
# 4  Hey guys, my name is Steviak and welcome to Su...
# 5  My restaurant. Big games. Big I think big game...
# 6  Hey, guys, it's Gravy, and I got a special gue...
# 7  \nHi, guys. It's Elite, and I'm back with anot...
# 8  Today we're gonna spend a bit of robots to get...
# 9  In today's Roblox video. I am the owner of my ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## 결과 파일 생성

# %%
lst_index = []

for col in df.columns:
    for i in range(1, 11):
        index = '{}_{}'.format(col, i)
        lst_index.append(index)

result = pd.concat([df['Adopt Me!'], df['MeepCity'], df['Tower of Hell'], df['Piggy'], df['Royale High'], df['Jailbreak'], 
                    df['Murder Mystery 2'], df['Welcome to Bloxburg'], df['Pizza Factory Tycoon'], df['Restaurant Tycoon']], axis=0)

result.index = lst_index
result = pd.DataFrame(result, columns=['original'])

# %%
result
# Out:
#                                                                original
# Adopt Me!_1           Actually, you know what? I'm gonna give you a ...
# Adopt Me!_2           Alright, guys, welcome back to another video. ...
# Adopt Me!_3           ABC for somebody to give me a fly ride. A ride...
# Adopt Me!_4           I made a brand new account that has absolutely...
# Adopt Me!_5           Hello everybody. Welcome back to my channel. A...
# ...                                                                 ...
# Restaurant Tycoon_6   My restaurant. Big games. Big I think big game...
# Restaurant Tycoon_7   Hey, guys, it's Gravy, and I got a special gue...
# Restaurant Tycoon_8   \nHi, guys. It's Elite, and I'm back with anot...
# Restaurant Tycoon_9   Today we're gonna spend a bit of robots to get...
# Restaurant Tycoon_10  In today's Roblox video. I am the owner of my ...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## 불용어

# %%
stop_words = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "f
will", "willing", "wish", "with", "within", "without", "wo", "won", "wonder", "wont", "won't", "words", "world", "would", "wouldn", "wouldnt", "wouldn't", "www", "x", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz"]

dic_slang = {
    'A': ['arse', 'arsehead', 'ass', 'asshole'],
    'B': ['bastard', 'bitch', 'bloody', 'bollocks', 'brotherfucker', 'bugger', 'bullshit'],
    'C': ['child-fucker', 'Christ on a bike', 'Christ on a cracker', 'cock', 'cocksucker', 'crap', 'cunt'],
    'D': ['damn', 'damn it', 'dick', 'dickhead', 'dyke'],
    'F': ['fatherfucker', 'fuck', 'frigger'],
    'G': ['goddamn', 'godsdamn'],
    'H': ['hell', 'holy shit', 'horeseshit'],
    'I': ['in shit'],
    'J': ['Jesus Christ', 'Jesus fuck', 'Jesus H. Christ', 'Jesus Harold Christ', 'Jesus wept', 'Jesus, Mary and Joseph'],
    'K': ['kike'],
    'M': ['motherfucker'],
    'N': ['nigga', 'nigra'],
    'P': ['piss', 'prick', 'pussy'],
    'S': ['shit', 'shit ass', 'shite', 'sisterfucker', 'slut', 'son of a bitch', 'son of a whore', 'spastic'],
    'T': ['turd', 'twat'],
    'W': ['wanker']
}

for key in dic_slang:
    stop_words += dic_slang[key]

# %%
stop_words[-20:]
# Out:
# ['Jesus wept',
#  'Jesus, Mary and Joseph',
#  'kike',
#  'motherfucker',
#  'nigga',
#  'nigra',
#  'piss',
#  'prick',
#  'pussy',
#  'shit',
#  'shit ass',
#  'shite',
#  'sisterfucker',
#  'slut',
#  'son of a bitch',
#  'son of a whore',
#  'spastic',
#  'turd',
#  'twat',
#  'wanker']

# %% [markdown]
# ### 작은 따옴표(')를 제외한 나머지 특수 문자 제거

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
symbols = string.punctuation.replace("'", "")
symbols
# Out:
# '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
for i in range(len(stop_words)):
    for symbol in symbols:
        stop_words[i] = stop_words[i].replace(symbol, "")

# %%
stop_words[-20:]
# Out:
# ['Jesus wept',
#  'Jesus Mary and Joseph',
#  'kike',
#  'motherfucker',
#  'nigga',
#  'nigra',
#  'piss',
#  'prick',
#  'pussy',
#  'shit',
#  'shit ass',
#  'shite',
#  'sisterfucker',
#  'slut',
#  'son of a bitch',
#  'son of a whore',
#  'spastic',
#  'turd',
#  'twat',
#  'wanker']

# %% [markdown]
# ### 소문자화

# %%
for i in range(len(stop_words)):
    stop_words[i] = stop_words[i].lower()

# %%
stop_words[-20:]
# Out:
# ['jesus wept',
#  'jesus mary and joseph',
#  'kike',
#  'motherfucker',
#  'nigga',
#  'nigra',
#  'piss',
#  'prick',
#  'pussy',
#  'shit',
#  'shit ass',
#  'shite',
#  'sisterfucker',
#  'slut',
#  'son of a bitch',
#  'son of a whore',
#  'spastic',
#  'turd',
#  'twat',
#  'wanker']

# %% [markdown]
# ### 원형 복원
# - n: nouns
# - v: verbs
# - a: adjectives
# - r: adverbs
# - s: satellite adjectives.

# %%
lm = WordNetLemmatizer()

stop_words = [lm.lemmatize(w, pos='n') for w in stop_words]
stop_words = [lm.lemmatize(w, pos='v') for w in stop_words]
stop_words = [lm.lemmatize(w, pos='a') for w in stop_words]
stop_words = [lm.lemmatize(w, pos='r') for w in stop_words]
stop_words = [lm.lemmatize(w, pos='s') for w in stop_words]
print('원형 복원 전 불용어 수: {}'.format(len(stop_words)))

stop_words = set(stop_words)
print('원형 복원 후 불용어 수: {}'.format(len(stop_words)))
# Out:
# 원형 복원 전 불용어 수: 1216
# 원형 복원 후 불용어 수: 1089

# %% [markdown]
# ## document

# %% [markdown]
# ### 작은 따옴표(')를 제외한 나머지 특수 문자, 줄바꿈, 공백 제거

# %%
def preprocessing(text):
    # 작은 따옴표(')를 제외한 나머지 특수 문자, 줄바꿈, 공백 제거
    for symbol in symbols:
        text = text.replace(symbol, "")
        text = text.replace('\n', "")
        text = text.strip()
        
    # 소문자화
    text = text.lower()
    
    # 원형 복원
    lm = WordNetLemmatizer()
    word_token = text.split()
    word_token = [lm.lemmatize(w, pos='n') for w in word_token]
    word_token = [lm.lemmatize(w, pos='v') for w in word_token]
    word_token = [lm.lemmatize(w, pos='a') for w in word_token]
    
    text = ' '.join(word_token)
    
    # 불용어 제거
    word_token = text.split(' ')
    
    lst_word = []
    for word in word_token:
        if word not in stop_words:
            lst_word.append(word)
            
    text = ' '.join(lst_word) + ' '
    
    ## 숫자제거 
    remove_number = re.compile(r'[0-9]')
    text = remove_number.sub('', text)
    
    ## 길이가 하나인 단어들 제거
    short_word = re.compile(r'\W*\b\w{1}\b')
    text = short_word.sub('', text)
    
    return text

# %%
df_video = df.applymap(preprocessing)

# %%
df_video
# Out:
#                                            Adopt Me!  \
# 0  gonna tomato cheese pizza sound gross money ha...
# 1  alright guy video episode account gonna play g...
# 2  abc fly ride ride potion abc today gonna trade...
# 3  brand account absolutely gonna poor adopt play...
# 4  channel today gonna request video december chr...
# 5  gosh man folk server fail bad ready cam star c...
# 6  whoa girl literally perfectly justin couple hi...
# 7  guy rare item game guy wait pet offensive adop...
# 8  cooky whirl whoa baby sleep nice relax crib ad...
# 9  today feel walk house eat kind bore leave hous...
#
#                                             MeepCity  \
# 0  hey guy class science class smack thing talk t...
# 1  yo guy boy alpha banger video guy guy today vi...
# 2  video vibri excite video play game blocksburg ...
# 3  lord big picme check check lol nice stand nice...
# 4  hey guy channel week upload roblox video time ...
# 5  today haymich city work routine chloe block vi...
# 6  man man pro head person capture single thing p...
# 7  guy'all marvelous night  guess today roadblock...
# 8  people master zubbie today review script basic...
# 9  hey guy channel cupcake today gonna play roblo...
#
#                                        Tower of Hell  \
# 0  roblox rage runner dan rage anger crew member ...
# 1  sense red extra gravity bounce level accountab...
# 2  hey guy alex zach drake twin jad charlie shut ...
# 3  girl girl god fast yeah wait low game guy audr...
# 4  dom queue understand domcue hurt tower beat ho...
# 5  today year play parkour tower type game cracky...
# 6  hey friend noodle roblox today hard roblox abb...
# 7  jake game channel silla mad today play roblox ...
# 8  excuse sir clothe concentrate wow play roblox ...
# 9  parcourt gonna tower gonna easy professional r...
#
# 3  mmm star guy joke customer money completely st...
# 4  hey guy steviak sushi tycoon roblox boy build ...
# 5  restaurant big game big big game suck suppose ...
# 6  hey guy gravy special guest gravy karliman dag...
# 7  guy elite video roadblock restaurant tycoon bu...
# 8  today gonna spend bite robot restaurant restau...
# 9  today roblox video owner restaurant scary guy ...

# %% [markdown]
# # 전략

# %% [markdown]
# 해당데이터가 각각의 기준에 들어있는지 확인

# %%
cnt_data
# Out:
#   Adopt Me! MeepCity Tower of Hell   Piggy Royale High Jailbreak  \
# 0     trade      bro          jump   piggy         guy       guy
# 1       pet    house           guy    yeah        time      wait
# 2       guy      guy          yeah     guy      outfit       cop
# 3    people     yeah          wait     god     diamond      yeah
# 4      wait     wait          time    wait        wait       car
# 5   grandpa    party          easy     key        high    arrest
# 6      neon     meat          game  shovel        cute    police
# 7      yeah     game           god    skin        dorm      card
# 8      feel     play           buy     die        yeah       key
# 9    dragon     cute         level    play       start     store
#
#   Murder Mystery 2 Welcome to Bloxburg Pizza Factory Tycoon Restaurant Tycoon
# 0              guy                 guy                pizza        restaurant
# 1         murderer                yeah                 yeah              yeah
# 2             wait                wait                  buy              cook
# 3          sheriff               pizza                 wait               guy
# 4             yeah               house                  guy             money
# 5             dude                room             customer             table
# 6             kill                time                money               buy
# 7              god                 eat               cheese            people
# 8              bro                girl                 cool              chef
# 9              gun                baby                  bro             thing

# %%
len(set(cnt_data[cnt_data.columns[1:]].values.flatten()))
# Out:
# 52

# %% [markdown]
# ## 만들려고 하는 데이터프레임의 column이 되는 단어들 만들기

# %% [markdown]
# ## Wordcount

# %%
games_li = ['Adopt Me!', 'MeepCity', 'Tower of Hell', 'Piggy',
       'Royale High', 'Jailbreak', 'Murder Mystery 2', 'Welcome to Bloxburg',
       'Pizza Factory Tycoon', 'Restaurant Tycoon']

### wordount
cnt_word_li = []

for game in games_li :
    cnt_word_li.extend(cnt_data[game].values)

columns_words = sorted(list(set(cnt_word_li)))

# %%
dic={}
for game in games_li : 
    for ii in range(10):
        variable_name = game + '_' + str(ii)
        dic[variable_name] = []
        lst_text = df_video[game].loc[ii].split(' ')
        for column in columns_words :
            dic[variable_name].append(lst_text.count(column))

# %%
new_cnt_df = pd.DataFrame(dic, index=columns_words).T
new_cnt_df
# Out:
#                      arrest  baby  bro  buy  car  card  cheese  chef  cook  \
# Adopt Me!_0               0    35    0    9    2     0       3     0     0
# Adopt Me!_1               0     0   17    0    0     0       0     0     0
# Adopt Me!_2               0     1    0    3    0     0       0     0     0
# Adopt Me!_3               0     0    0    1    0     0       0     0     0
# Adopt Me!_4               0     2    0    0    0     0       0     0     0
# ...                     ...   ...  ...  ...  ...   ...     ...   ...   ...
# Restaurant Tycoon_5       0     0    3    5    0     0       0     0     3
# Restaurant Tycoon_6       0     0    2   50    1     0       2    14    30
# Restaurant Tycoon_7       0     0    0    3    0     0       0     3     0
# Restaurant Tycoon_8       0     0    0    5    0     0       1    13     3
# Restaurant Tycoon_9       0     0    5   14    0     0       0     4     9
#
#                      cool  ...  shovel  skin  start  store  table  thing  \
# Adopt Me!_0             1  ...       0     0      0     21      0      2
# Adopt Me!_1             3  ...       0     0      6      0      0      3
# Adopt Me!_2             2  ...       0     0      2      0      0      3
# Adopt Me!_3             1  ...       0     0      1      0      0      1
# Adopt Me!_4             3  ...       0     0      2      0      0      2
# ...                   ...  ...     ...   ...    ...    ...    ...    ...
# Restaurant Tycoon_5     1  ...       0     0      5      2      2      2
# Restaurant Tycoon_6     2  ...       0     0      0      2     14     11
# Restaurant Tycoon_7     2  ...       0     0      9      1     20      3
# Restaurant Tycoon_8     0  ...       0     0      2      2     12      4
# Restaurant Tycoon_9     1  ...       0     0      1      1     12      8
#
#                      time  trade  wait  yeah
# Adopt Me!_0             8      0     6    18
# Adopt Me!_1             4     22     2     3
# Adopt Me!_2             2     28     1     3
# Adopt Me!_3             3     49    19     3
# Adopt Me!_4             5     56     1     1
# ...                   ...    ...   ...   ...
# Restaurant Tycoon_5     5      0     4     2
# Restaurant Tycoon_6     3      1    16    29
# Restaurant Tycoon_7     0      0     1     7
# Restaurant Tycoon_8     3      0     8     3
# Restaurant Tycoon_9     3      0     9     4
#
# [100 rows x 58 columns]

# %%
# new_cnt_df.to_csv('wordcount_top10_for_tsne.csv')

# %% [markdown]
# ## Fisher's exact Test

# %%
### fisher's exact test 
fisher_word_li = []

for game in games_li :
    fisher_word_li.extend(fisher_data[game].values)
columns_words = sorted(list(set(fisher_word_li)))

# %%
dic={}
for game in games_li : 
    for ii in range(10):
        variable_name = game + '_' + str(ii)
        dic[variable_name] = []
        lst_text = df_video[game].loc[ii].split(' ')
        for column in columns_words :
            dic[variable_name].append(lst_text.count(column))

# %%
new_fisher_df = pd.DataFrame(dic, index=columns_words).T
new_fisher_df
# Out:
#                      adopt  arrest  babe  baby  banana  bank  beat  bella  \
# Adopt Me!_0             14       0     0    35       0     0     1      0
# Adopt Me!_1              1       0     0     0       0     0     2      0
# Adopt Me!_2              0       0     0     1       0     0     1      0
# Adopt Me!_3              9       0     0     0       0     0     0      0
# Adopt Me!_4              6       0     0     2       0     0     0      0
# ...                    ...     ...   ...   ...     ...   ...   ...    ...
# Restaurant Tycoon_5      0       0     0     0       1     0     1      0
# Restaurant Tycoon_6      0       0     0     0       0     0     0      0
# Restaurant Tycoon_7      0       0     0     0       0     0     0      0
# Restaurant Tycoon_8      0       0     0     0       0     0     0      0
# Restaurant Tycoon_9      0       0     0     0       0     0     0      0
#
#                      birthday  blocksburg  ...  skirt  snow  spaghetti  sushi  \
# Adopt Me!_0                 0           0  ...      0     0          0      0
# Adopt Me!_1                 0           0  ...      0     0          0      0
# Adopt Me!_2                 0           0  ...      0     0          0      0
# Adopt Me!_3                 0           0  ...      0     3          0      0
# Adopt Me!_4                 0           0  ...      0     0          0      0
# ...                       ...         ...  ...    ...   ...        ...    ...
# Restaurant Tycoon_5         0           0  ...      0     0          0      0
# Restaurant Tycoon_6         0           0  ...      0     0          0      0
# Restaurant Tycoon_7         0           0  ...      0     0          0      0
# Restaurant Tycoon_8         0           0  ...      0     0          0      0
# Restaurant Tycoon_9         0           0  ...      0     0          0      1
#
#                      table  teacher  tower  trade  trap  waiter
# Adopt Me!_0              0        0      0      0     0       0
# Adopt Me!_1              0        0      0     22     0       0
# Adopt Me!_2              0        0      0     28     0       0
# Adopt Me!_3              0        0      0     49     0       0
# Adopt Me!_4              0        0      2     56     0       0
# ...                    ...      ...    ...    ...   ...     ...
# Restaurant Tycoon_5      2        0      0      0     0       0
# Restaurant Tycoon_6     14        0      0      1     0      18
# Restaurant Tycoon_7     20        0      0      0     0       0
# Restaurant Tycoon_8     12        0      0      0     0      14
# Restaurant Tycoon_9     12        0      0      0     0       3
#
# [100 rows x 99 columns]

# %%
# new_fisher_df.to_csv('fisherexact_top10_for_tsne.csv')

# %% [markdown]
# ## Tf-Idf

# %%
### Tf-Idf방법
tfidf_word_li = []

for game in games_li :
    tfidf_word_li.extend(tfidf_data[game].values)

columns_words = sorted(list(set(tfidf_word_li)))

# %%
dic={}
for game in games_li : 
    for ii in range(10):
        variable_name = game + '_' + str(ii)
        dic[variable_name] = []
        lst_text = df_video[game].loc[ii].split(' ')
        for column in columns_words :
            dic[variable_name].append(lst_text.count(column))

# %%
new_tfidfcount_df = pd.DataFrame(dic, index=columns_words).T
new_tfidfcount_df
# Out:
#                      adopt  arrest  bella  blocksburg  bro  buy  car  card  \
# Adopt Me!_0             14       0      0           0    0    9    2     0
# Adopt Me!_1              1       0      0           0   17    0    0     0
# Adopt Me!_2              0       0      0           0    0    3    0     0
# Adopt Me!_3              9       0      0           0    0    1    0     0
# Adopt Me!_4              6       0      0           0    0    0    0     0
# ...                    ...     ...    ...         ...  ...  ...  ...   ...
# Restaurant Tycoon_5      0       0      0           0    3    5    0     0
# Restaurant Tycoon_6      0       0      0           0    2   50    1     0
# Restaurant Tycoon_7      0       0      0           0    0    3    0     0
# Restaurant Tycoon_8      0       0      0           0    0    5    0     0
# Restaurant Tycoon_9      0       0      0           0    5   14    0     0
#
#                      carrot  checkpoint  ...  shovel  skin  skirt  table  \
# Adopt Me!_0               0           0  ...       0     0      0      0
# Adopt Me!_1               0           0  ...       0     0      0      0
# Adopt Me!_2               0           0  ...       0     0      0      0
# Adopt Me!_3               0           0  ...       0     0      0      0
# Adopt Me!_4               0           0  ...       0     0      0      0
# ...                     ...         ...  ...     ...   ...    ...    ...
# Restaurant Tycoon_5       0           0  ...       0     0      0      2
# Restaurant Tycoon_6       0           0  ...       0     0      0     14
# Restaurant Tycoon_7       0           0  ...       0     0      0     20
# Restaurant Tycoon_8       0           0  ...       0     0      0     12
# Restaurant Tycoon_9       0           0  ...       0     0      0     12
#
#                      time  tower  trade  wait  waiter  yeah
# Adopt Me!_0             8      0      0     6       0    18
# Adopt Me!_1             4      0     22     2       0     3
# Adopt Me!_2             2      0     28     1       0     3
# Adopt Me!_3             3      0     49    19       0     3
# Adopt Me!_4             5      2     56     1       0     1
# ...                   ...    ...    ...   ...     ...   ...
# Restaurant Tycoon_5     5      0      0     4       0     2
# Restaurant Tycoon_6     3      0      1    16      18    29
# Restaurant Tycoon_7     0      0      0     1       0     7
# Restaurant Tycoon_8     3      0      0     8      14     3
# Restaurant Tycoon_9     3      0      0     9       3     4
#
# [100 rows x 69 columns]

# %%
# new_tfidfcount_df.to_csv('tfidf_top10_for_tsne.csv')
